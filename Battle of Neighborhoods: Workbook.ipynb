# %% [markdown]
# ## Importing the required packages

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import numpy as np

import json 

from geopy.geocoders import Nominatim

import requests
from pandas.io.json import json_normalize

import matplotlib.cm as cm
import matplotlib.colors as colors

import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Getting the location coordinates of Canada's 5 largest cities

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="tor_explorer")
tor_location = geolocator.geocode(address)
tor_latitude = tor_location.latitude
tor_longitude = tor_location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(tor_latitude, tor_longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
address = 'Montreal, QC'

geolocator = Nominatim(user_agent="mon_explorer")
mon_location = geolocator.geocode(address)
mon_latitude = mon_location.latitude
mon_longitude = mon_location.longitude
print('The geograpical coordinate of Montreal are {}, {}.'.format(mon_latitude, mon_longitude))
# Out:
# The geograpical coordinate of Montreal are 45.4972159, -73.6103642.

# %%
address = 'Vancouver, BC'

geolocator = Nominatim(user_agent="van_explorer")
van_location = geolocator.geocode(address)
van_latitude = van_location.latitude
van_longitude = van_location.longitude
print('The geograpical coordinate of Montreal are {}, {}.'.format(van_latitude, van_longitude))
# Out:
# The geograpical coordinate of Montreal are 49.2608724, -123.1139529.

# %%
address = 'Calgary, AB'

geolocator = Nominatim(user_agent="cal_explorer")
cal_location = geolocator.geocode(address)
cal_latitude = cal_location.latitude
cal_longitude = cal_location.longitude
print('The geograpical coordinate of Calgary are {}, {}.'.format(cal_latitude, cal_longitude))
# Out:
# The geograpical coordinate of Calgary are 51.0534234, -114.0625892.

# %%
address = 'Edmonton, AB'

geolocator = Nominatim(user_agent="edm_explorer")
edm_location = geolocator.geocode(address)
edm_latitude = edm_location.latitude
edm_longitude = edm_location.longitude
print('The geograpical coordinate of Edmonton are {}, {}.'.format(edm_latitude, edm_longitude))
# Out:
# The geograpical coordinate of Edmonton are 53.535411, -113.507996.

# %% [markdown]
# ## Creating a pandas dataframe of the geographic coordinates

# %% [markdown]
# ## Setting up Foursquare Credentials and Version

# %%
CLIENT_ID = 'OQVU2YIU1H5HPJSAYWHPZYJBUVK14EZ1CNENWGIFYNIVVXG4'
CLIENT_SECRET = 'MFDWS3IIHETUOH3QTQN1ZCHTE1DFR4WOXOX4KIHUGHV4X4XS'
VERSION = '20180605'

# %% [markdown]
# ## Requesting Foursquare Venues for Each City

# %% [markdown]
# ### Toronto, ON
# #### Results 0-100

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 0
tor_url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    tor_latitude, 
    tor_longitude, 
    radius, 
    LIMIT,
    offset)
tor_results1 = requests.get(tor_url1).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
tor_venues1 = tor_results1['response']['groups'][0]['items']
    
tor_nearby_venues1 = json_normalize(tor_venues1) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
tor_nearby_venues1 =tor_nearby_venues1.loc[:, filtered_columns]

# filter the category for each row
tor_nearby_venues1['venue.categories'] = tor_nearby_venues1.apply(get_category_type, axis=1)

# clean columns
tor_nearby_venues1.columns = [col.split(".")[-1] for col in tor_nearby_venues1.columns]

# %% [markdown]
# #### Results 101-200

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 100
tor_url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    tor_latitude, 
    tor_longitude, 
    radius, 
    LIMIT,
    offset)
tor_results2 = requests.get(tor_url2).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
tor_venues2 = tor_results2['response']['groups'][0]['items']
    
tor_nearby_venues2 = json_normalize(tor_venues2) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
tor_nearby_venues2 =tor_nearby_venues2.loc[:, filtered_columns]

# filter the category for each row
tor_nearby_venues2['venue.categories'] = tor_nearby_venues2.apply(get_category_type, axis=1)

# clean columns
tor_nearby_venues2.columns = [col.split(".")[-1] for col in tor_nearby_venues2.columns]

# %% [markdown]
# ### Montreal, ON
# #### Results 0-100

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 0
mon_url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    mon_latitude, 
    mon_longitude, 
    radius, 
    LIMIT,
    offset)
mon_results1 = requests.get(mon_url1).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
mon_venues1 = mon_results1['response']['groups'][0]['items']
    
mon_nearby_venues1 = json_normalize(mon_venues1) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
mon_nearby_venues1 =mon_nearby_venues1.loc[:, filtered_columns]

# filter the category for each row
mon_nearby_venues1['venue.categories'] = mon_nearby_venues1.apply(get_category_type, axis=1)

# clean columns
mon_nearby_venues1.columns = [col.split(".")[-1] for col in mon_nearby_venues1.columns]

# %% [markdown]
# #### Results 101-200

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 100
mon_url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    mon_latitude, 
    mon_longitude, 
    radius, 
    LIMIT,
    offset)
mon_results2 = requests.get(mon_url2).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
mon_venues2 = mon_results2['response']['groups'][0]['items']
    
mon_nearby_venues2 = json_normalize(mon_venues2) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
mon_nearby_venues2 =mon_nearby_venues2.loc[:, filtered_columns]

# filter the category for each row
mon_nearby_venues2['venue.categories'] = mon_nearby_venues2.apply(get_category_type, axis=1)

# clean columns
mon_nearby_venues2.columns = [col.split(".")[-1] for col in mon_nearby_venues2.columns]

# %% [markdown]
# ### Vancouver, ON
# #### Results 0-100

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 0
van_url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    van_latitude, 
    van_longitude, 
    radius, 
    LIMIT,
    offset)
van_results1 = requests.get(van_url1).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
van_venues1 = van_results1['response']['groups'][0]['items']
    
van_nearby_venues1 = json_normalize(van_venues1) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
van_nearby_venues1 =van_nearby_venues1.loc[:, filtered_columns]

# filter the category for each row
van_nearby_venues1['venue.categories'] = van_nearby_venues1.apply(get_category_type, axis=1)

# clean columns
van_nearby_venues1.columns = [col.split(".")[-1] for col in van_nearby_venues1.columns]

# %% [markdown]
# #### Results 101-200

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 100
van_url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    van_latitude, 
    van_longitude, 
    radius, 
    LIMIT,
    offset)
van_results2 = requests.get(van_url2).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
van_venues2 = van_results2['response']['groups'][0]['items']
    
van_nearby_venues2 = json_normalize(van_venues2) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
van_nearby_venues2 =van_nearby_venues2.loc[:, filtered_columns]

# filter the category for each row
van_nearby_venues2['venue.categories'] = van_nearby_venues2.apply(get_category_type, axis=1)

# clean columns
van_nearby_venues2.columns = [col.split(".")[-1] for col in van_nearby_venues2.columns]

# %% [markdown]
# ### Edmonton, ON
# #### Results 0-100

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 0
edm_url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    edm_latitude, 
    edm_longitude, 
    radius, 
    LIMIT,
    offset)
edm_results1 = requests.get(edm_url1).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
edm_venues1 = edm_results1['response']['groups'][0]['items']
    
edm_nearby_venues1 = json_normalize(edm_venues1) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
edm_nearby_venues1 =edm_nearby_venues1.loc[:, filtered_columns]

# filter the category for each row
edm_nearby_venues1['venue.categories'] = edm_nearby_venues1.apply(get_category_type, axis=1)

# clean columns
edm_nearby_venues1.columns = [col.split(".")[-1] for col in edm_nearby_venues1.columns]

# %% [markdown]
# #### Results 101-200

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 100
edm_url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    edm_latitude, 
    edm_longitude, 
    radius, 
    LIMIT,
    offset)
edm_results2 = requests.get(edm_url2).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
edm_venues2 = edm_results2['response']['groups'][0]['items']
    
edm_nearby_venues2 = json_normalize(edm_venues2) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
edm_nearby_venues2 =edm_nearby_venues2.loc[:, filtered_columns]

# filter the category for each row
edm_nearby_venues2['venue.categories'] = edm_nearby_venues2.apply(get_category_type, axis=1)

# clean columns
edm_nearby_venues2.columns = [col.split(".")[-1] for col in edm_nearby_venues2.columns]

# %% [markdown]
# ### Calgary, ON
# #### Results 0-100

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 0
cal_url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    cal_latitude, 
    cal_longitude, 
    radius, 
    LIMIT,
    offset)
cal_results1 = requests.get(cal_url1).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
cal_venues1 = cal_results1['response']['groups'][0]['items']
    
cal_nearby_venues1 = json_normalize(cal_venues1) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
cal_nearby_venues1 =cal_nearby_venues1.loc[:, filtered_columns]

# filter the category for each row
cal_nearby_venues1['venue.categories'] = cal_nearby_venues1.apply(get_category_type, axis=1)

# clean columns
cal_nearby_venues1.columns = [col.split(".")[-1] for col in cal_nearby_venues1.columns]

# %% [markdown]
# #### Results 101-200

# %%
LIMIT = 10000000 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

offset = 100
cal_url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    cal_latitude, 
    cal_longitude, 
    radius, 
    LIMIT,
    offset)
cal_results2 = requests.get(cal_url2).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
cal_venues2 = cal_results2['response']['groups'][0]['items']
    
cal_nearby_venues2 = json_normalize(cal_venues2) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
cal_nearby_venues2 =cal_nearby_venues2.loc[:, filtered_columns]

# filter the category for each row
cal_nearby_venues2['venue.categories'] = cal_nearby_venues2.apply(get_category_type, axis=1)

# clean columns
cal_nearby_venues2.columns = [col.split(".")[-1] for col in cal_nearby_venues2.columns]

# %% [markdown]
# ### Merging Tables by City then Count by Category

# %%
#Merging Toronto 
tor_merged = tor_nearby_venues1.append(tor_nearby_venues2, ignore_index = True)
tor_count=tor_merged.groupby('categories').count()
tor_count
# Out:
#                                name  lat  lng
# categories
# American Restaurant               2    2    2
# Aquarium                          1    1    1
# Art Gallery                       1    1    1
# Arts & Crafts Store               1    1    1
# Asian Restaurant                  3    3    3
# Athletics & Sports                2    2    2
# BBQ Joint                         1    1    1
# Bakery                            6    6    6
# Bar                               1    1    1
# Baseball Stadium                  1    1    1
# Basketball Stadium                1    1    1
# Beer Bar                          4    4    4
# Beer Store                        1    1    1
# Bookstore                         2    2    2
# Brewery                           2    2    2
# Bubble Tea Shop                   1    1    1
# Butcher                           1    1    1
# Café                             12   12   12
# Caribbean Restaurant              1    1    1
# ...

# %%
#Merging Montreal 
mon_merged = mon_nearby_venues1.append(mon_nearby_venues2, ignore_index = True)
mon_count=mon_merged.groupby('categories').count()
mon_count
# Out:
#                                name  lat  lng
# categories
# Art Museum                        1    1    1
# Asian Restaurant                  1    1    1
# BBQ Joint                         2    2    2
# Bagel Shop                        2    2    2
# Bakery                           10   10   10
# Bar                               1    1    1
# Beer Bar                          3    3    3
# Bookstore                         3    3    3
# Breakfast Spot                    3    3    3
# Brewery                           1    1    1
# Burger Joint                      2    2    2
# Café                             30   30   30
# Canal                             1    1    1
# Cheese Shop                       1    1    1
# Chocolate Shop                    1    1    1
# Church                            2    2    2
# Climbing Gym                      1    1    1
# Clothing Store                    1    1    1
# Cocktail Bar                      2    2    2
# ...

# %%
#Merging Vancouver 
van_merged = van_nearby_venues1.append(van_nearby_venues2, ignore_index = True)
van_count=van_merged.groupby('categories').count()
van_count
# Out:
#                                name  lat  lng
# categories
# American Restaurant               2    2    2
# Art Gallery                       1    1    1
# Asian Restaurant                  1    1    1
# BBQ Joint                         1    1    1
# Bagel Shop                        2    2    2
# Bakery                           10   10   10
# Beach                             3    3    3
# Beer Bar                          1    1    1
# Belgian Restaurant                2    2    2
# Bookstore                         2    2    2
# Boxing Gym                        1    1    1
# Breakfast Spot                    3    3    3
# Brewery                           3    3    3
# Building                          1    1    1
# Burger Joint                      1    1    1
# Café                              4    4    4
# Cheese Shop                       1    1    1
# Chinese Restaurant                1    1    1
# Chocolate Shop                    1    1    1
# ...

# %%
#Merging Edmonton 
edm_merged = edm_nearby_venues1.append(edm_nearby_venues2, ignore_index = True)
edm_count=edm_merged.groupby('categories').count()
edm_count
# Out:
#                                name  lat  lng
# categories
# American Restaurant               3    3    3
# Asian Restaurant                  1    1    1
# Athletics & Sports                1    1    1
# BBQ Joint                         4    4    4
# Bakery                            6    6    6
# Bank                              3    3    3
# Bar                               3    3    3
# Bookstore                         1    1    1
# Breakfast Spot                    1    1    1
# Brewery                           3    3    3
# Burger Joint                      2    2    2
# Butcher                           1    1    1
# Café                              9    9    9
# Cajun / Creole Restaurant         1    1    1
# Cheese Shop                       1    1    1
# Chinese Restaurant                2    2    2
# Coffee Shop                      18   18   18
# College Gym                       2    2    2
# College Residence Hall            1    1    1
# ...

# %%
#Merging Calgary 
cal_merged = cal_nearby_venues1.append(cal_nearby_venues2, ignore_index = True)
cal_count=cal_merged.groupby('categories').count()
cal_count
# Out:
#                                  name  lat  lng
# categories
# American Restaurant                 1    1    1
# Argentinian Restaurant              1    1    1
# Asian Restaurant                    2    2    2
# Athletics & Sports                  2    2    2
# BBQ Joint                           3    3    3
# Bakery                              5    5    5
# Bar                                 3    3    3
# Board Shop                          1    1    1
# Bookstore                           1    1    1
# Breakfast Spot                      4    4    4
# Brewery                             7    7    7
# Burger Joint                        3    3    3
# Café                                3    3    3
# Cajun / Creole Restaurant           1    1    1
# Camera Store                        1    1    1
# Chinese Restaurant                  4    4    4
# Cocktail Bar                        2    2    2
# Coffee Shop                         8    8    8
# ...
